# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.request import HTTPError
#from urllib.error import HTTPError
import urllib.request
from urllib import parse
from urllib.parse import urlparse

# %%
info=['동창생','몬스터','사이코메트리','럭키','패신저스','좋은 친구들','하루','아수라','정글북','라이프','마스터','루시드 드림','베리 굿 걸','라이언','니드 포 스피드','더 시그널','도희야','더 건맨','더 기버: 기억전달자','제로 다크 서티','피터와 드래곤','베이블레이드 버스트 갓 : 갓 발키리의 탄생','셀프/리스','다이노소어 어드벤처 : 백악기 공룡대백과','터키','존 윅','극장판 소드 아트 온라인 -오디널 스케일-','감바의 대모험','퇴마: 무녀굴','라스트 위치 헌터','극장판 도라에몽: 진구의 비밀도구 박물관','배우는 배우다','마이펫 오지','시간위의 집','눈길','버틀러: 대통령의 집사','리딕','나의 절친 악당들','맨홀','극장판 도라에몽: 진구의 남극 꽁꽁 대모험','극장판 꼬마버스 타요의 에이스 구출작전','제 5침공','워터 디바이너','극장판 아이엠스타 : 꿈의 오디션!','극장판 또봇: 로봇군단의 습격','가시','장난감이 살아있다','우먼 인 골드','은밀한 유혹','여교사','미라클 벨리에','레고 배트맨 무비','미스컨덕트','워킹걸','익스펜더블 3','달빛궁궐','화장','꾸뻬씨의 행복여행','폴리스 스토리 2014','더 자이언트','히든 카드','예수는 역사다','빅','아메리칸 울트라','대배우','매직브러시','톱스타','부활','문라이트','라스트베가스','심야식당','레전드','해양경찰 마르코','플로렌스','19곰 테드 2','글로리데이','50가지 그림자: 심연','컬러풀 웨딩즈','덤 앤 더머 투','무현, 두 도시 이야기','더 퍼지','스누피: 더 피너츠 무비','발레리나','핵소 고지','로마 위드 러브','덕수리 5형제','연애의 맛','원피스 필름 골드','짱구는 못말려 극장판:태풍을 부르는 나와 우주의 프린세스','빅풋 주니어','송 포 유','언프렌디드: 친구삭제','노아의 방주: 남겨진 녀석들','잡스','한공주','분노의 윤리학','극장판 루팡 3세 VS 명탐정 코난','일곱난쟁이','쓰리데이즈 투 킬','비행기','드림 쏭','세이빙 산타','트랜스포터: 리퓰드','순정','창문 넘어 도망친 100세 노인','아이 엠 어 히어로','툼스톤','레고 무비','그레이스 오브 모나코','헤라클레스 : 레전드 비긴즈','비밀은 없다','소셜포비아','밤의 여왕','노벰버 맨','닌자터틀 : 어둠의 히어로','독수리 에디','함정','더 셰프','언브로큰','마야','투모로우랜드','저스틴','파이스토리 : 악당상어 소탕작전','괴물의 아이','짱구는 못말려 극장판 : 정면승부! 로봇아빠의 역습','짱구는 못말려 극장판: 폭풍수면! 꿈꾸는 세계 대돌격','헨젤과 그레텔: 마녀 사냥꾼 3D','존 윅 - 리로드','눈의 여왕','극장판 안녕 자두야','사랑에 대한 모든 것','다이노 타임','목소리의 형태','혼숨','내 사랑','앨빈과 슈퍼밴드: 악동 어드벤처','이스케이프 플랜','포인트 브레이크','러브, 로지','오즈의 마법사: 돌아온 도로시','프랑켄슈타인: 불멸의 영웅','구스범스','빌리와 용감한 녀석들 2','위대한 소원','주피터 어센딩','비행기 2: 소방구조대','패딩턴','미녀와 야수','레드카펫','뮨: 달의 요정','차이니즈 조디악','극적인 하룻밤','아빠를 빌려드립니다','비정규직 특수요원','아기배달부 스토크','스폰지밥 3D','캐롤','선 오브 갓','미나문방구','안나 카레니나','팬','에베레스트','백 투 더 비기닝','사랑하기 때문에','노리개','자백','스포트라이트','최강전사 미니특공대 : 새로운 악당의 습격','최강전사 미니특공대: 영웅의 탄생','오즈 그레이트 앤드 파워풀','싱글라이더','석조저택 살인사건','그녀','경성학교: 사라진 소녀들','클로버필드 10번지','홈','숲속으로','그레이의 50가지 그림자','론 서바이버','블루 재스민','카페 소사이어티','플립','장고:분노의 추적자','헤이트풀8','보통사람','소수의견','천재 강아지 미스터 피바디','나의 독재자','내 심장을 쏴라','판타스틱 4','닌자터틀','나의 소녀시대','무뢰한','다이버전트','신이 보낸 사람','나를 잊지 말아요','스머프: 비밀의 숲','터닝메카드W: 블랙미러의 부활','창수','원라인','남과 여','어느날','오피스','헌츠맨: 윈터스 워','빅쇼트','바람이 분다','클라우드 아틀라스','노브레싱','어쌔신 크리드','실버라이닝 플레이북','아메리칸 허슬','조이','리얼','마담 뺑덕','순수의 시대','위험한 상견례 2','트리플 엑스 리턴즈','주온 : 끝의 시작','넛잡: 땅콩 도둑들','조선미녀삼총사','카3: 새로운 도전','R.I.P.D. : 알.아이.피.디.','인서전트','다이버전트 시리즈: 얼리전트','비포 미드나잇','보이후드','캐치미','무서운 이야기 2','개를 훔치는 완벽한 방법','도라에몽 : 스탠 바이 미','기생수 파트1','로봇, 소리','거울나라의 앨리스','퍼시 잭슨과 괴물의 바다','헬머니','맨 프롬 UNCLE','킹 아서: 제왕의 검','노예 12년','가려진 시간','히든 피겨스','소녀괴담','론 레인저','더 큐어','극장판 요괴워치: 탄생의 비밀이다냥!','극장판 요괴워치: 염라대왕과 5개의 이야기다냥!','메카닉: 리크루트','아이스 에이지: 지구 대충돌','스텝 업: 올 인','그레이트 월','섀도우 헌터스: 뼈의 도시','응징자','치외법권','링컨','스파이 브릿지','마이 리틀 자이언트','어린왕자','47 미터','황제를 위하여','타잔 3D','다이노소어 어드벤처 3D','우는 남자','서부전선','패션왕','짱구는 못말려 극장판: 나의 이사 이야기 선인장 대습격','극장판 짱구는 못말려 : 습격!! 외계인 덩덩이','더 임파서블','오큘러스','위자: 저주의 시작','조선마술사','잭 리처: 네버 고 백','널 기다리며','플랜맨','사냥','아빠는 딸','그날의 분위기','엔더스 게임','트롤','앵그리버드 더 무비','더 울프 오브 월스트리트','픽셀','트랜센던스','국가대표 2','더 파이브','런던 해즈 폴른','스플릿','공각기동대 : 고스트 인 더 쉘','안녕, 헤이즐','리오 2','관능의 법칙','하늘에서 음식이 내린다면 2','카트','그랜드 부다페스트 호텔','브리짓 존스의 베이비','하늘을 걷는 남자','얼라이드','인시디어스 3','손님','대립군','좋아해줘','살인의뢰','몬스터 대학교','썬더와 마법저택','로빈슨 크루소','갓 오브 이집트','개구쟁이 스머프 2','협녀, 칼의 기억','해어화','크루즈 패밀리','미 비포 유','월터의 상상은 현실이 된다','에픽 : 숲속의 전설','로보캅','아메리칸 스나이퍼','설리: 허드슨강의 기적','애나벨','불한당: 나쁜 놈들의 세상','프리즈너스','시카리오: 암살자의 도시','컨택트','눈의 여왕 2: 트롤의 마법거울','눈의 여왕 3: 눈과 불의 마법대결','미쓰 와이프','방황하는 칼날','맨 인 더 다크','잭 라이언 : 코드네임 쉐도우','신데렐라','그놈이다','날, 보러와요','박물관이 살아있다 : 비밀의 무덤','성난 변호사','명탐정 코난:은빛 날개의 마술사','명탐정 코난 : 수평선상의 음모','명탐정 코난 : 탐정들의 진혼가','명탐정 코난 : 코난 실종사건 - 사상 최악의 이틀','명탐정 코난: 에피소드 원-작아진 명탐정','고령화 가족','간신','미씽: 사라진 여자','워크래프트: 전쟁의 서막','장수상회','슬로우 비디오','웜 바디스','빅매치','더 웹툰: 예고살인','시간이탈자','해빙','악녀','깡철이','찌라시: 위험한 소문','롤러코스터','허삼관','특별수사: 사형수의 편지','셜록: 유령신부','백악관 최후의 날','사우스포','매그니피센트 7','극장판 포켓몬스터 베스트위시: 신의 속도 게노세크트, 뮤츠의 각성','극장판 포켓몬스터 XY : 파괴의 포켓몬과 디안시','포켓몬 더 무비 XY 후파: 광륜의 초마신','포켓몬 더 무비 XY&Z 「볼케니온 : 기계왕국의 비밀」','루돌프와 많이있어','전국노래자랑','도리화가','남자사용설명서','상의원','명탐정 코난 : 이차원의 저격수','명탐정 코난 : 화염의 해바라기','명탐정 코난: 순흑의 악몽','명탐정 코난:진홍의 연가','하이힐','우리는 형제입니다','드라큘라: 전설의 시작','미스터 고','굿 다이노','특별시민','뽀로로 극장판 슈퍼썰매 대모험','뽀로로 극장판 컴퓨터 왕국 대모험','말레피센트','열정같은소리하고있네','벤허','런닝맨','탐정 홍길동: 사라진 마을','다이하드: 굿 데이 투 다이','인간중독','차이나타운','해무(海霧)','위대한 개츠비','오블리비언','300: 제국의 부활','더 폰','라이프 오브 파이','임금님의 사건수첩','러시 : 더 라이벌','하트 오브 더 씨','인페르노','마다가스카의 펭귄','피끓는 청춘','콩: 스컬 아일랜드','파파로티','샌 안드레아스','고질라','로그 원: 스타워즈 스토리','씽','두근두근 내 인생','죽여주는 여자','공범','엘리시움','채피','나를 찾아줘','007 스펙터','집으로 가는 길','오늘의 연애','터보','노무현입니다','남자가 사랑할 때','테이큰 3','노아','봉이 김선달','뷰티 인사이드','화이트 하우스 다운','인디펜던스 데이 : 리써전스','인투 더 스톰','몽타주','굿바이 싱글','루시','겟 아웃','폼페이: 최후의 날','레지던트 이블: 파멸의 날','나의 사랑 나의 신부','원더 우먼','강남 1970','악의 연대기','버드맨','레버넌트: 죽음에서 돌아온 자','애프터 어스','23 아이덴티티','모아나','결혼전야','당신, 거기 있어줄래요','화이: 괴물을 삼킨 아이','몬스터 호텔','몬스터 호텔 2','이미테이션 게임','보스 베이비','연애의 온도','특종: 량첸살인기','조작된 도시','슈퍼배드 2','마이펫의 이중생활','기술자들','퍼시픽 림','열한시','쎄시봉','남쪽으로 튀어','제보자','보안관','탐정 : 더 비기닝','도리를 찾아서','라이트 아웃','애나벨 : 인형의 주인','우아한 거짓말','오빠생각','나우 유 씨 미 : 마술사기단','전설의 주먹','고산자, 대동여지도','논스톱','런 올 나이트','언더 워터','헝거게임: 캣칭 파이어','헝거게임: 모킹제이','헝거게임: 더 파이널','빅 히어로','미스 페레그린과 이상한 아이들의 집','스파이','고스트버스터즈','앤트맨','대니쉬 걸','캡틴 필립스','제이슨 본','또 하나의 약속','재심','프리즌','분노의 질주: 더 맥시멈','스타트렉 비욘드','형','레드: 더 레전드','드래곤 길들이기 2','스물','캐리비안의 해적: 죽은 자는 말이 없다','청년경찰','더 울버린','로건','그래비티','퓨리','수어사이드 스쿼드','데드풀','표적','계춘할망','어바웃 타임','신의 한 수','귀향','인턴','미이라','분노의 질주: 더 익스트림','너의 이름은.','역린','조선명탐정 : 사라진 놉의 딸','매드 맥스: 분노의 도로','박수건달','캡틴 아메리카: 윈터 솔져','쿵푸팬더3','비긴 어게인','싱 스트리트','타짜-신의 손','가디언즈 오브 갤럭시','가디언즈 오브 갤럭시 VOL. 2','용의자','어메이징 스파이더맨 2','맨 오브 스틸','배트맨 대 슈퍼맨: 저스티스의 시작','판도라','스토커','아가씨','엣지 오브 투모로우','주토피아','군도: 민란의 시대','님아, 그 강을 건너지 마오','스타트렉 다크니스','스타워즈: 깨어난 포스','지.아이.조 2','나우 유 씨 미 2','인사이드 아웃','혹성탈출: 반격의 서막','혹성탈출: 종의 전쟁','위플래쉬','라라랜드','월드 워 Z','호빗: 스마우그의 폐허','호빗: 다섯 군대 전투','검은 사제들','닥터 스트레인지','쥬라기 월드','메이즈 러너','메이즈 러너: 스코치 트라이얼','레전드 오브 타잔','신비한 동물사전','더 테러 라이브','덕혜옹주','감기','미니언즈','슈퍼배드 3','친구 2','극비수사','숨바꼭질','장산범','연평해전','킹스맨 : 시크릿 에이전트','토르: 다크 월드','터미네이터 제니시스','신세계','대호','곡성','잭 리처','미션 임파서블: 로그네이션','은밀하게 위대하게','인천상륙작전','감시자들','스파이더맨: 홈 커밍','밀정','카운슬러','엑소더스: 신들과 왕들','마션','에이리언: 커버넌트','컨저링','인시디어스: 두번째 집','분노의 질주: 더 세븐','컨저링 2','트랜스포머: 사라진 시대','13시간','트랜스포머: 최후의 기사','잭 더 자이언트 킬러','엑스맨: 데이즈 오브 퓨처 패스트','엑스맨: 아포칼립스','수상한 그녀','캡틴 아메리카: 시빌 워','아이언맨 3','내부자들','내부자들: 디 오리지널','택시운전사','설국열차','옥자','검사외전','겨울왕국','어벤져스: 에이지 오브 울트론','변호인','부산행','서울역','소원','사도','동주','박열','암살','7번방의 선물','인터스텔라','덩케르크','국제시장','관상','더 킹','해적: 바다로 간 산적','히말라야','명량','마이 리틀 히어로','끝까지 간다','터널','공조','베를린','베테랑','군함도']

# %%
# 네이버 기사수
art=[]

for n in info:
    try:
        k = urllib.parse.quote(n)
        url ='https://search.naver.com/search.naver?ie=utf8&where=news&query=%EC%98%81%ED%99%94%20{}&sm=tab_pge&sort=0&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:r,p:all,a:all&mynews=0&cluster_rank=84&start=1&refresh_start=0'.format(k)
        webpage=urlopen(url)
        source = BeautifulSoup(webpage,'html5lib')
        article = source.find('div',{'class':'title_desc all_my'})
        art.append(n + '\t' + article.get_text().strip())
    except AttributeError:
        pass      
#with codecs.open('article.txt', 'w', encoding = 'utf-8') as f:
with open('naver_article.txt', 'w', encoding = 'utf-8') as f:
        for i in art:
            f.write(i + '\n')
        f.close()

# %%
#다음 평점/코멘트 수
art=[]
 # n은 1~11만 (최근 개봉영화가 11만)
for n in range(1,5):
    try:
        url ="http://movie.daum.net/moviedb/grade?movieId={}".format(n)
        webpage=urlopen(url)
        source = BeautifulSoup(webpage,'html5lib')
        title =source.find("h2",{'class':'tit_rel'})
        count =source.find('span',{'class','score_rating'})
        article = source.find('span',{'class':'num_review'})
        art.append(title.get_text() + '\t' + count.get_text()+'\t'+article.get_text().strip())
    except AttributeError:
        pass      
with open('daum_comment.txt', 'w', encoding = 'utf-8') as f:
        for i in art:
            f.write(i + '\n')
        f.close()
